# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt

# %%
img2 = imageio.imread('test2.jpeg') # image is imported as 3D matrix of type 'uint8'
img2 = np.asarray(img2,dtype='int')  # convert from uint8 to integer
im2 = img2[:,:,0]
X = np.zeros([9,1600])
l = 40
k = 0
for i in range(3):
    for j in range(3):
        X[k,:] = im2[l*i:l*(i+1),l*j:l*(j+1)].flatten()
        k += 1

# %%
fig = plt.figure(figsize=(24, 18), dpi=240, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace=0.06, wspace=-0.85)
for i in range (1,10):
    ax = fig.add_subplot(l,l,i)
    xs = X[i-1].reshape(40,40)
    ax.imshow(xs,cmap='gray')
    plt.axis('off')
    
plt.show()

# %%
nc = 100    #reduce 1600 data to 100 principal components
pca2 = PCA(n_components=nc)
Xpc = pca2.fit_transform(X)
Xt = pca2.inverse_transform(Xpc)  #reconstruct faces from 100 principal components


fig = plt.figure(figsize=(24, 18), dpi=240, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace=0.04, wspace=-0.78)
for i in range (1,10):
    ax = fig.add_subplot(l,l,i)
    xs = Xt[i-1].reshape(40,40)
    ax.imshow(xs,cmap='gray')
    plt.axis('off')

# %%
Xpc.shape
# Out:
# (9, 9)
